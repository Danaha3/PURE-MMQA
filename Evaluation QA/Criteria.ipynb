# %% [markdown]
#  # Q&A Evaluation using 8 diffrent craterias
#  4 crateria for question evaulation: q_clarity, passage_relevance, answerability and task_relevance
#  and 4 crateria for answer evaluation:

# %%
CRITERIA = {
    # --- A.3: Question-level criteria ----------
    "q_clarity": {
        "level": "question",
        "name": "Question Clarity & Conciseness",
        "inputs": ["question"],
        "definition": "Assesses whether the question is clearly expressed, grammatically well-formed, unambiguous, concise and free from unnecessary or redundant wording.",
        "cot": [
            "Step 1: Read the question to understand its intended meaning.",
            "Step 2: Assess whether the question is grammatically correct and syntactically well-formed.",
            "Step 3: Determine whether the question is clear, unambiguous, and easy to understand.",
            "Step 4: Check whether the question contains redundant, repetitive, vague, or unnecessary wording that could be removed without changing the meaning.",
            "Step 5: Assign a score according to the rubric (0/1/2).",
            "Step 6: Provide a concise one-sentence justification focusing only on clarity, grammar, ambiguity, and conciseness."
        ],
        "rubric": {
            0: "The question is unclear, ambiguous, grammatically flawed, or contains excessive redundancy that makes it difficult to understand.",
            1: "The question is mostly clear and understandable but contains minor grammatical issues, awkward phrasing, or some redundancy that slightly affects clarity.",
            2: "The question is clear, unambiguous, grammatically correct, and concise, with no unnecessary or redundant wording."
        }
    },

    "q_passage_relevance": {
        "level": "question",
        "name": "Question & Passage Relevance",
        "inputs": ["question", "passage", "image"],
        "definition": "Assesses how well the question is topically aligned with the content of the cited passage or multimodal evidence.",
        "cot": [
            "Step 1: Read the question.",
            "Step 2: Identify the primary entities and topics in the question.",
            "Step 3: Scan the cited passage or inspect the referenced multimodal evidence.",
            "Step 4: Assess whether the question targets the central content or aspect of the passage or multimodal evidence.",
            "Step 5: Assign a score according to the rubric (0/1/2).",
            "Step 6: Provide a concise one-sentence justification explaining the topical connection between the question and the cited passage or multimodal evidence."
        ],
        "rubric": {
            0: "The question is unrelated to the cited passage or multimodal evidence.",
            1: "The question is partially related or focuses on a minor, secondary, or weakly connected aspect of the cited passage or multimodal evidence.",
            2: "The question is highly relevant to the cited passage or multimodal evidence."
        }
    },

    "q_answerability": {
        "level": "question",
        "name": "Answerability",
        "inputs": ["question", "passage", "image"],
        "definition": "Evaluates whether the cited passage or multimodal evidence provides sufficient information to fully answer the question without relying on external knowledge or assumptions.",
        "cot": [
            "Step 1: Read the question and identify the information required to answer it.",
            "Step 2: Examine the cited passage or multimodal evidence for relevant supporting information.",
            "Step 3: Assess whether all parts of the question can be answered using the provided cited passage or multimodal evidence.",
            "Step 4: Identify any missing, implicit, or insufficient information.",
            "Step 5: Assign a score according to the rubric (0/1/2).",
            "Step 6: Provide a concise one-sentence justification explaining whether the cited passage or multimodal evidence is sufficient to answer the question."
        ],
        "rubric": {
            0: "The question cannot be answered using the cited passage or evidence.",
            1: "The question can be partially answered, but some required information is missing, implicit, ambiguous, or incomplete.",
            2: "The question can be fully and directly answered using the cited passage or evidence."
        }
    },

    "task_relevance": {
        "level": "question",
        "name": "Task Relevance",
        "inputs": ["question", "task"],
        "definition": "Assesses whether the question aligns with the intended task objective and definition.",
        "cot": [
            "Step 1: Read the provided task name and task definition.",
            "Step 2: Read the question and identify its main purpose.",
            "Step 3: Determine whether the question asks for information that matches the task objective and focus.",
            "Step 4: Assign a score according to the rubric (0/1/2).",
            "Step 5: Provide a concise one-sentence justification explaining the degree of alignment between the question and the task objective."
        ],
        "rubric": {
            0: "The question does not align with the task objective or is off-task.",
            1: "The question is partially aligned with the task objective.",
            2: "The question is fully aligned with the task objective."
        }
    },

    # --- A.4: Answer-level criteria ----------
    "a_Clarity": {
        "level": "answer",
        "name": "Answer Clarity, Fluency & Understandability",
        "inputs": ["answer"],
        "definition": "Evaluates whether the answer is clearly written, grammatically correct, fluent, coherent, and easy to understand.",
        "cot": [
            "Step 1: Read the answer independently of the evidence.",
            "Step 2: Check whether the answer is grammatically correct and free from language errors.",
            "Step 3: Assess whether the wording is clear, fluent, and naturally phrased.",
            "Step 4: Determine whether the answer is easy to read and understand without ambiguity.",
            "Step 5: Assign a score according to the rubric (0/1/2).",
            "Step 6: Provide a concise one-sentence justification for the assigned score."
        ],
        "rubric": {
            0: "The answer is unclear, incoherent, or ambiguous and/or contains major grammatical errors or awkward phrasing, making it difficult to read and understand.",
            1: "The answer's meaning can be inferred but lacks full clarity, and may contain minor grammatical issues, though it remains understandable.",
            2: "The answer is clear, coherent, fluent, unambiguous, grammatically correct, and easily understood."
        }
    },

    "a_faithfulness": {
        "level": "answer",
        "name": "Answer Faithfulness (Evidence Alignment)",
        "inputs": ["question", "answer", "passage", "image"],
        "definition": "Assesses whether factual claims in the answer are grounded and supported by the cited passage or multimodal evidence without hallucination.",
        "cot": [
            "Step 1: Read the cited passage and inspect multimodal evidence to identify the required information and key facts, such as requirements, constraints, entities, and relationships it contains.",
            "Step 2: Read the answer and identify its main factual claims.",
            "Step 3: Check whether each factual claim in the answer is explicitly stated or clearly grounded and supported by the cited passage or multimodal evidence.",
            "Step 4: Identify any unsupported, weakly supported, contradicted, or hallucinated claims.",
            "Step 5: Assign a score according to the rubric (0/1/2).",
            "Step 6: Provide a concise one-sentence justification explaining whether the answer is grounded and supported by the cited evidence."
        ],
        "rubric": {
            0: "The answer is off-topic, unsupported, contradicted, or contains hallucinated claims.",
            1: "The answer is partially grounded and supported by the cited passage but includes some unsupported, weakly supported, or slightly misaligned claims.",
            2: "The answer is fully grounded and supported with no hallucination."
        }
    },

    "a_correctness": {
        "level": "answer",
        "name": "Answer Correctness & Completeness",
        "inputs": ["question", "answer", "passage", "image"],
        "definition": "Assesses whether the answer correctly and completely addresses the question based on the cited passage or multimodal evidence.",
        "cot": [
            "Step 1: Read the question and identify all information required to answer it fully.",
            "Step 2: Read the cited passage and multimodal evidence to determine the correct evidence-supported answer.",
            "Step 3: Read the answer and verify whether its factual claims are consistent with the cited evidence.",
            "Step 4: Assess whether the answer includes all essential information needed to fully address the question.",
            "Step 5: Check for factual errors, contradictions, or missing important details.",
            "Step 6: Assign a score according to the rubric (0/1/2).",
            "Step 7: Provide a concise one-sentence justification explaining the level of correctness and completeness."
        ],
        "rubric": {
            0: "The answer is incorrect or incomplete.",
            1: "The answer is mostly correct but incomplete, missing important details, or partially addresses the question.",
            2: "The answer is fully correct and complete."
        }
    },

    "a_difficulty": {
        "level": "answer",
        "name": "Difficulty Appropriateness",
        "inputs": ["question", "answer", "difficulty", "passage", "image"],
        "definition": "Assesses whether the assigned difficulty label is appropriate for the retrieval and reasoning effort required to answer.",
        "cot": [
            "Step 1: Read the question, answer, cited passage, multimodal evidence, and assigned difficulty label such as Easy or Hard.",
            "Step 2: Identify the evidence required to answer the question correctly, such as key facts, constraints, steps, entities, and relationships.",
            "Step 3: Determine the retrieval or evidence pattern required: single-hop means the answer can be found in one local span with minimal inference, while multi-hop means the answer requires combining information from multiple spans and connecting them logically.",
            "Step 4: Assess whether the generated answer actually demonstrates the required reasoning and evidence integration.",
            "Step 5: Compare the estimated retrieval and reasoning cost to the assigned difficulty label.",
            "Step 6: Assign a score according to the rubric (0/1/2).",
            "Step 7: Provide a concise one-sentence justification explaining the evidence pattern, such as single-hop, multi-hop, or cross-section reasoning."
        ],
        "rubric": {
            0: "The difficulty label is clearly mismatched with the retrieval and reasoning effort required.",
            1: "The difficulty label is partially matched, but the required evidence pattern or reasoning effort is not fully reflected.",
            2: "The difficulty label is well matched to the retrieval and reasoning effort required."
        }
    }
}
