# %% [markdown]
# ## Prepare TASK type,  definition , SubTask and fewshot in Dictionary "tasks"
#
# ![image.png](attachment:image.png)

# %%
tasks = {
    "GOV": {
        "name": "Requirements Governance",
        "subtasks": [
            "Business Rule Analysis",
            "Risk Management"
        ],
        "definition": """This task involves:
1. **Business Rule Analysis**: Focuses on identifying business policies, regulations, and constraints that govern how a system or organization must operate. These may relate to strategic planning, objectives, regulatory compliance, or internal processes.
  **Query Focus**: Questions that aim to extract or clarify business constraints, rules, or operational policies defined in the requirements document (e.g., deadlines, permissions, regulations).
  **Question Examples**:
    - At what step does a business rule X apply?
    - What are the embedded constraints (e.g., deadlines, geography)?
    - What are the business rule requirements for this project X?
    - What is the stated scope of the project X?
    - List all business objectives for the project X.
    - What are the stated goals for project X?
    - Which regulatory or compliance standards apply to System X (if any)? (e.g., industry regulations — healthcare, finance, government, automotive;data handling — personal or cardholder data; system/architecture — cloud hosting, third-party vendors; or geographic laws.)
    - What constraints for system X? (e.g. Memory constraint, software or hardware constraint, or any other attribute constraint)
    -List the business rules stated in the SRS and any cited sources (e.g., laws, standards, internal policies). If none are cited, mark Not specified.”
    - What priority level or criticality is assigned to requirement X -if any- ?



2. **Risk Management**: Involves identifying potential risks, hazards, or failure points that could negatively affect the system. Includes mitigation strategies and contingency planning.
  **Query Focus**: Questions about threats, issue frequency, or compliance risks.
  **Question Examples**:
    - What are the consequences of a specific hazard?
    - What are the system’s top 3 risks?
    - What is the frequency of this type of issue occurring?
    - Under what conditions might  requirement X be fail (risks/exceptions)?
"""
    },

    "EVL": {
        "name": "Requirements Evaluation",
        "subtasks": [
            "Metrics",
            "Quality"
        ],
        "definition": """This task involves:
1. **Metrics**: Quantitative measures used to assess requirement characteristics such as completeness, traceability, or test coverage.
  **Query Focus**: Queries focused on measurement, such as counting, computing maxima, or evaluating averages.
  **Question Examples**:
    - How many non-functional requirements are documented in the SRS?
    - How many total requirements are in this specification?
    - How many functional requirements are documented in the SRS?
    - What parameter values, ranges, or constraints are explicitly documented for requirement X -if applicable- in the SRS?
    - What performance indicators or quality metrics are documented in the SRS for requirement X or the overall system?

2. **Quality**: Assessing the quality of individual requirements and the overall specification to identify ambiguities, inconsistencies, or missed items.
  **Query Focus**: Queries targeting requirement quality, such as clarity, completeness, or ambiguity.
  **Question Examples**:
    - Are all requirements traced to a stakeholder need?
    - Find all ambiguous words in the requirements.
    -What are the requirement quality attributes for the system X?
    -What are the performance requirements of the system?
    -What performance-related requirements or constraints are documented in the SRS?
    -What constraints documented in the SRS relate to performance, maintainability, or testability ..etc of requirement X?
    -Which are requirement quality attributes for requirement  X?
    -What postconditions or success conditions -if any- for requirement X are specified in the SRS?
    -What validation conditions are specified in the SRS for requirement X?
    -According to the SRS, what is Acceptance criteria for requirement X ?
    -What acceptance criteria are specified in the SRS for requirement X?-if applicable-
"""
    },

    "EXE": {
        "name": "Requirements Execution",
        "subtasks": [
            "Process"
        ],
        "definition": """This task involves:

1. **Process**: Requirements Execution and Process Workflow define how requirements are executed at runtime through ordered system actions, decisions, module responsibilities, triggers, data flows, and interactions across system components, actors, and interfaces.
  **Query Focus**: Queries related to requirement execution, including workflow steps, decision logic, triggers, responsibilities, data and control flows, actor interactions, and execution conditions, inputs, and outcomes.
  **Question Examples**:
    - What external interfaces must the system support? (e.g. user interface, hardware Interfaces, software Interfaces, communication interfaces)
    - What are the steps or processes to apply business rule X?
    - What are the steps or processes to apply requirement  X?
    - How does the SRS describe the implementation for requirement X (e.g., algorithms, workflows, standards, or design details)?
    - Describe the control or process flow for requirement X?
    - In which module, channel, interface, or system component is requirement X specified to take place?
    - What cases or conditions (e.g., triggers, exceptions) are specified for requirement X in the SRS?
    - What preconditions or triggers -if any- for requirement X are documented in the SRS?
    - What functional action or behavior is requirement X will perform?
    - Under what conditions might  requirement X be invoked ?
    - What inputs, outputs, data  elements or assumptions  are specified for requirement X in the SRS?

"""
    },

    "DIS": {
        "name": "Requirements Discovery",
        "subtasks": [
            "Search",
            "Stakeholder Analysis"
        ],
        "definition": """This task involves:
1. **Search**: Retrieving relevant requirements or related information based on queries, including traceability, rationale, and data provenance.
  **Query Focus**: Queries that search documents or artifacts to retrieve relevant information through matching rules or free-text queries.
  **Question Examples**:
    - Which requirements are related to requirement "xyz"?
    - Does the requirement match a business objective?
    - In which module, section, or use-case is requirement X defined to apply?
    - What constraints for requirement X in the SRS?
    - What constraints are documented for or requirment  X?
    - List all non-functional requirements in the document X.
    - List all functional requirements in the document X.
    - List all requirements in the document X.
    - Which requirement mentions security?
    - Which requirement mentions performance?
    - Which requirement in the SRS explicitly use the UI element X?
    - Which requirement in the SRS explicitly use the input X or data X?
    - - According to the SRS, what differences/similarities are documented between requirements and requirement Y? - especially if similar functions like log in as user, log in as admin



2. **Stakeholder Analysis**: Identifying stakeholders and analyzing their roles, needs, and interactions with the system.
  **Query Focus**: Queries targeting individuals or groups (e.g., customers, suppliers, users).
  **Question Examples**:
    - For a given requirement, who are the stakeholders of interest?
    - What kind of users are going to use the system?
    - For business rule A, who is the originating stakeholder or source?
    - Who are the stakeholders involved in a specific business rule?
    - List all user and actor types in the SRS as intended to use or interact with the system?
    - “For each business rule, list the SRS roles/actors explicitly affected (if stated). If not stated, mark Not specified.”
    - Which usage scenarios or use-cases describe how users X interact with the system?
    - Which stakeholder, user role, or system actor is identified in the SRS as responsible for or interacting with requirement X?
    - Which stakeholder, user or system actor is specified in the SRS as the user or initiator of requirement X?
"""
    }
}
